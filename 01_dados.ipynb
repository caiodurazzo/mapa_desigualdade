# %% [markdown]
# ## Dados

# %% [markdown]
# Nesse notebook são construídos os dados da análise

# %% [markdown]
# Fonte: https://institutocidadessustentaveis.shinyapps.io/mapadesigualdadesaopaulo2025/

# %%
import pandas as pd
from utils.save_csv import save_csv

# %%
dados = [
    ("Consolação", 71.09),
    ("Moema", 70.98),
    ("Alto de Pinheiros", 70.65),
    ("Itaim Bibi", 70.19),
    ("Lapa", 69.35),
    ("Barra Funda", 68.58),
    ("Perdizes", 68.33),
    ("Pinheiros", 68.00),
    ("Vila Mariana", 67.94),
    ("Butantã", 67.58),
    ("Santo Amaro", 66.12),
    ("Saúde", 64.23),
    ("Carrão", 63.69),
    ("Vila Prudente", 63.35),
    ("Bom Retiro", 63.26),
    ("Jardim Paulista", 63.14),
    ("Campo Grande", 62.98),
    ("Morumbi", 62.67),
    ("Liberdade", 62.43),
    ("Jaguara", 62.40),
    ("Jaguaré", 62.34),
    ("República", 62.07),
    ("Cidade Dutra", 62.02),
    ("Água Rasa", 61.62),
    ("Ermelino Matarazzo", 61.58),
    ("Bela Vista", 61.52),
    ("Parque do Carmo", 61.50),
    ("Vila Leopoldina", 61.35),
    ("Pari", 61.17),
    ("Vila Matilde", 61.08),
    ("Moóca", 60.96),
    ("Socorro", 60.96),
    ("Tatuapé", 60.90),
    ("Ipiranga", 60.65),
    ("Anhanguera", 60.60),
    ("Vila Formosa", 60.46),
    ("Jardim Helena", 59.94),
    ("Sé", 59.88),
    ("Vila Sônia", 59.73),
    ("Freguesia do Ó", 59.67),
    ("José Bonifácio", 59.54),
    ("Artur Alvim", 59.50),
    ("Cambuci", 59.47),
    ("Marsilac", 59.11),
    ("São Lucas", 59.06),
    ("Parelheiros", 59.00),
    ("Vila Andrade", 58.90),
    ("São Domingos", 58.69),
    ("Tucuruvi", 58.69),
    ("Aricanduva", 58.67),
    ("Sacomã", 58.67),
    ("Jabaquara", 58.40),
    ("Vila Jacuí", 58.31),
    ("Perus", 58.27),
    ("Casa Verde", 58.19),
    ("Mandaqui", 57.81),
    ("Cangaíba", 57.77),
    ("Cidade Líder", 57.75),
    ("Pirituba", 57.69),
    ("São Rafael", 57.60),
    ("Jardim São Luís", 57.44),
    ("Santa Cecília", 57.29),
    ("Cursino", 57.27),
    ("Brás", 57.00),
    ("Iguatemi", 56.98),
    ("Campo Belo", 56.88),
    ("Sapopemba", 56.77),
    ("Rio Pequeno", 56.71),
    ("Santana", 56.69),
    ("Raposo Tavares", 56.65),
    ("Vila Guilherme", 56.65),
    ("Belém", 56.42),
    ("Cidade Tiradentes", 56.42),
    ("Guaianases", 55.77),
    ("Campo Limpo", 55.60),
    ("Jardim Ângela", 55.27),
    ("São Miguel", 55.17),
    ("São Mateus", 55.10),
    ("Penha", 54.96),
    ("Vila Curuçá", 54.92),
    ("Cachoeirinha", 54.88),
    ("Limão", 54.74),
    ("Itaquera", 54.67),
    ("Grajaú", 54.46),
    ("Ponte Rasa", 54.12),
    ("Jaraguá", 53.73),
    ("Capão Redondo", 53.33),
    ("Lajeado", 53.25),
    ("Pedreira", 52.90),
    ("Vila Maria", 52.85),
    ("Tremembé", 51.08),
    ("Itaim Paulista", 50.77),
    ("Jaçanã", 50.69),
    ("Cidade Ademar", 50.23),
    ("Vila Medeiros", 48.88),
    ("Brasilândia", 47.27),
]

# %%
df = pd.DataFrame(dados, columns=["distrito", "pontuacao"])

# %%
save_csv(df, "dados.csv")
# Out:
# Base salva em data\dados.csv
